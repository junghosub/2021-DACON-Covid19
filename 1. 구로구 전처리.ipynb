# %% [markdown]
# # 1. 구로구 데이터 전처리

# %%
# 전처리를 위한 라이브러리
import pandas as pd

# %%
# 데이터 불러오기
del_call = pd.read_csv('data/KT_빅데이터플랫폼_데이터셋/dlvr_call.csv')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3147: DtypeWarning: Columns (19) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# 구로구만 살펴보기
guro = del_call[del_call['DLVR_STORE_SIGNGU_NM'] == '구로구'].reset_index(drop = True)
guro = guro[guro['DLVR_REQUST_STTUS_VALUE'] == 1]
print(guro.shape)
guro.head()
# Out:
# (352453, 32)
#         SN  PROCESS_DT DLVR_REQUST_ENTRPS_ID  DLVR_REQUST_STTUS_VALUE  \
# 0  3486946  2019-12-01               C000049                        1
# 1  3486960  2019-12-01               C000049                        1
# 2  3486964  2019-12-01               C000049                        1
# 3  3486978  2019-12-01               C000049                        1
# 4  3486982  2019-12-01               C000049                        1
#
#   DLVR_RCEPT_ENTRPS_ID DLVR_STORE_ID DLVR_STORE_INDUTY_NM  \
# 0              C000049      S0022458                패스트푸드
# 1              C000049      S0022440                패스트푸드
# 2              C000049      S0000200                   분식
# 3              C000049      S0000267                    회
# 4              C000237      S0000135                   치킨
#
#    DLVR_STORE_LEGALDONG_CODE DLVR_STORE_BRTC_NM DLVR_STORE_SIGNGU_NM  ...  \
# 0                 1153010800              서울특별시                  구로구  ...
# ...

# %% [markdown]
# ### 배달 상품금액

# %%
# 배달 상품금액이 0인 데이터
guro[guro['GOODS_AMOUNT'] == 0].reset_index(drop = True)
# Out:
#             SN  PROCESS_DT DLVR_REQUST_ENTRPS_ID  DLVR_REQUST_STTUS_VALUE  \
# 0      3487177  2019-12-01               C000049                        1
# 1      3487241  2019-12-01               C000049                        1
# 2      3487256  2019-12-01               C000049                        1
# 3      3487276  2019-12-01               C000049                        1
# 4      3487330  2019-12-01               C000049                        1
# ...        ...         ...                   ...                      ...
# 33289  7749851  2020-03-31               C000210                        1
# 33290  7750157  2020-03-31               C000210                        1
# 33291  7750163  2020-03-31               C000049                        1
# 33292  7750238  2020-03-31               C000210                        1
# 33293  7750468  2020-03-31               C000049                        1
#
#       DLVR_RCEPT_ENTRPS_ID DLVR_STORE_ID DLVR_STORE_INDUTY_NM  \
# ...

# %% [markdown]
# 배달 상품금액이 0인 데이터가 약 3만개 가량 있다. 상식적으로 배달 상품금액이 0일 수는 없다. 기프티콘이나 쿠폰을 통해 구매한게 아닐까 싶다. 하지만 차후 분석에서 배달 금액을 이용해야하기 때문에 편의상 제외하도록 하였다.

# %%
# 배달 상품금액이 0인 넘는 데이터만 보기
guro = guro[guro['GOODS_AMOUNT'] > 0]

# %%
# 가게와 배달 목적지의 도로명 주소 코드를 str 타입으로 변경해주기
guro['DLVR_STORE_RDNMADR_CODE'] = guro['DLVR_STORE_RDNMADR_CODE'].astype('string')
guro['DLVR_DSTN_RDNMADR_CODE'] = guro['DLVR_DSTN_RDNMADR_CODE'].astype('string')

# %% [markdown]
# ### 도로명 주소 변환

# %%
# 배달상점도로명주소 코드
list(guro['DLVR_STORE_RDNMADR_CODE'].value_counts().index)
# Out:
# ['1.15304E+11',
#  '115304148103',
#  '115304148098',
#  '115303000028',
#  '115304148301',
#  '\\N',
#  '115304148083',
#  '1.15303E+11',
#  '115303000022',
#  '115303116003',
#  '115304148422',
#  '115303116001',
#  '115303116010',
#  '115303000023',
#  '115304148089',
#  '115304148138',
#  '115304148090',
#  '115302000003',
#  '115304148076',
#  '115304148267',
#  '115304148146',
#  '115304148179',
#  '115304148463',
#  '115304148035',
#  '115304148214',
#  '115304148137',
#  '115304148027',
#  '115304148075',
#  '115304148133',
#  '115303116009',
#  '115303000019',
#  '115304148300',
#  '115304148043',
#  '115304148079',
#  '115304148092',
#  '115303116002',
#  '115304148383',
#  '115303005070',
#  '115303005068',
#  '115304148123',
#  '115304148074',
#  '115303116016',
#  '115304148071',
#  '115304148153',
#  '115304148291',
#  '1.15302E+11',
#  '115304148033',
#  '115304148360',
#  '115304148294',
#  '115304148018',
#  '115303000020',
#  '115304148465',
#  '115304148128',
# ...

# %%
# 배달상점 도로명주소 코드 변환
guro['DLVR_STORE_RDNMADR_CODE'].replace('1.15302E+11', '115302000000', inplace = True)
guro['DLVR_STORE_RDNMADR_CODE'].replace('1.15303E+11', '115303000000', inplace = True)
guro['DLVR_STORE_RDNMADR_CODE'].replace('1.15304E+11', '115304000000', inplace = True)

# %%
# 배달목적지도로명주소 코드

list(guro['DLVR_DSTN_RDNMADR_CODE'].value_counts().index.unique())
# Out:
# ['1.15304E+11',
#  '115303000028',
#  '\\N',
#  '1.15303E+11',
#  '115303116003',
#  '115304148075',
#  '115303116016',
#  '115304148049',
#  '115304148077',
#  '115303000022',
#  '115304148179',
#  '115304148027',
#  '115304148300',
#  '115304148031',
#  '114704142095',
#  '115304148138',
#  '115304148463',
#  '115303005068',
#  '4.12104E+11',
#  '115302000003',
#  '115304148291',
#  '114703005066',
#  '4.12103E+11',
#  '115304148055',
#  '115304148366',
#  '412103187028',
#  '115303116009',
#  '115304148468',
#  '114703114001',
#  '115304148292',
#  '115304148092',
#  '1.14704E+11',
#  '115303000020',
#  '115304148123',
#  '412103187024',
#  '115303116006',
#  '115304148467',
#  '115304148289',
#  '115304148105',
#  '115304148465',
#  '115304148036',
#  '115304148148',
#  '1.14703E+11',
#  '115303000021',
#  '115304148053',
#  '115304148458',
#  '115304148136',
#  '115303000023',
#  '115304148422',
#  '115304148071',
#  '114704142117',
#  '412103187038',
#  '115304148073',
# ...

# %%
# 배달목적지도로명주소 코드 변환
guro['DLVR_DSTN_RDNMADR_CODE'].replace('1.14702E+11', '114702000000', inplace = True)
guro['DLVR_DSTN_RDNMADR_CODE'].replace('1.14703E+11', '114703000000', inplace = True)
guro['DLVR_DSTN_RDNMADR_CODE'].replace('1.14704E+11', '114704000000', inplace = True)

guro['DLVR_DSTN_RDNMADR_CODE'].replace('1.15302E+11', '115302000000', inplace = True)
guro['DLVR_DSTN_RDNMADR_CODE'].replace('1.15303E+11', '115303000000', inplace = True)
guro['DLVR_DSTN_RDNMADR_CODE'].replace('1.15304E+11', '115304000000', inplace = True)
guro['DLVR_DSTN_RDNMADR_CODE'].replace('1.15305E+11', '115305000000', inplace = True)
guro['DLVR_DSTN_RDNMADR_CODE'].replace('1.15452E+11', '115452000000', inplace = True)
guro['DLVR_DSTN_RDNMADR_CODE'].replace('1.15453E+11', '115453000000', inplace = True)
guro['DLVR_DSTN_RDNMADR_CODE'].replace('1.15454E+11', '115454000000', inplace = True)

guro['DLVR_DSTN_RDNMADR_CODE'].replace('1.15902E+11', '115902000000', inplace = True)
guro['DLVR_DSTN_RDNMADR_CODE'].replace('1.15904E+11', '115904000000', inplace = True)

guro['DLVR_DSTN_RDNMADR_CODE'].replace('1.15602E+11', '115602000000', inplace = True)
guro['DLVR_DSTN_RDNMADR_CODE'].replace('1.15603E+11', '115603000000', inplace = True)
guro['DLVR_DSTN_RDNMADR_CODE'].replace('1.15604E+11', '115604000000', inplace = True)

guro['DLVR_DSTN_RDNMADR_CODE'].replace('1.16202E+11', '116202000000', inplace = True)
guro['DLVR_DSTN_RDNMADR_CODE'].replace('1.16203E+11', '116203000000', inplace = True)
guro['DLVR_DSTN_RDNMADR_CODE'].replace('1.16204E+11', '116204000000', inplace = True)

guro['DLVR_DSTN_RDNMADR_CODE'].replace('4.12102E+11', '412102000000', inplace = True)
guro['DLVR_DSTN_RDNMADR_CODE'].replace('4.12103E+11', '412103000000', inplace = True)
guro['DLVR_DSTN_RDNMADR_CODE'].replace('4.12104E+11', '412104000000', inplace = True)

guro['DLVR_DSTN_RDNMADR_CODE'].replace('4.11903E+11', '411903000000', inplace = True)
guro['DLVR_DSTN_RDNMADR_CODE'].replace('4.11904E+11', '411904000000', inplace = True)

# %%
list(guro['DLVR_DSTN_RDNMADR_CODE'].value_counts().index.unique())
# Out:
# ['115304000000',
#  '115303000028',
#  '\\N',
#  '115303000000',
#  '115303116003',
#  '115304148075',
#  '115303116016',
#  '115304148049',
#  '115304148077',
#  '115303000022',
#  '115304148179',
#  '115304148027',
#  '115304148300',
#  '115304148031',
#  '114704142095',
#  '115304148138',
#  '115304148463',
#  '115303005068',
#  '412104000000',
#  '115302000003',
#  '115304148291',
#  '114703005066',
#  '412103000000',
#  '115304148055',
#  '115304148366',
#  '412103187028',
#  '115303116009',
#  '115304148468',
#  '114703114001',
#  '115304148292',
#  '115304148092',
#  '114704000000',
#  '115303000020',
#  '115304148123',
#  '412103187024',
#  '115303116006',
#  '115304148467',
#  '115304148289',
#  '115304148105',
#  '115304148465',
#  '115304148036',
#  '115304148148',
#  '114703000000',
#  '115303000021',
#  '115304148053',
#  '115304148458',
#  '115304148136',
#  '115303000023',
#  '115304148422',
#  '115304148071',
#  '114704142117',
#  '412103187038',
#  '115304148073',
# ...

# %%
# 이상치 
anomaly = guro[(guro['DLVR_STORE_RDNMADR_CODE'] == '\\N') | (guro['DLVR_DSTN_RDNMADR_CODE'] == '\\N')].reset_index(drop = True)
anomaly
# Out:
#             SN  PROCESS_DT DLVR_REQUST_ENTRPS_ID  DLVR_REQUST_STTUS_VALUE  \
# 0      3487018  2019-12-01               C000049                        1
# 1      3487198  2019-12-01               C000049                        1
# 2      3487821  2019-12-01               C000049                        1
# 3      3487836  2019-12-01               C000049                        1
# 4      3488026  2019-12-01               C000049                        1
# ...        ...         ...                   ...                      ...
# 27654  7749247  2020-03-31               C000049                        1
# 27655  7750015  2020-03-31               C000049                        1
# 27656  7750225  2020-03-31               C000049                        1
# 27657  7750413  2020-03-31               C000049                        1
# 27658  7750431  2020-03-31               C000049                        1
#
#       DLVR_RCEPT_ENTRPS_ID DLVR_STORE_ID DLVR_STORE_INDUTY_NM  \
# ...

# %%
anomaly[['DLVR_STORE_LEGALDONG_NM', 'DLVR_STORE_RDNMADR_CODE',  'DLVR_DSTN_LEGALDONG_NM', 'DLVR_DSTN_RDNMADR_CODE']]
# Out:
#       DLVR_STORE_LEGALDONG_NM DLVR_STORE_RDNMADR_CODE DLVR_DSTN_LEGALDONG_NM  \
# 0                         오류동            115303000028                     항동
# 1                         천왕동                      \N                    오류동
# 2                         오류동            115303000028                    오류동
# 3                         고척동            115303005068                    개봉동
# 4                         개봉동            115304148138                    신정동
# ...                       ...                     ...                    ...
# 27654                     개봉동                      \N                    개봉동
# 27655                     개봉동                      \N                    개봉동
# 27656                     오류동                      \N                    오류동
# 27657                     개봉동                      \N                    광명동
# 27658                     고척동            115304000000                    고척동
#
#       DLVR_DSTN_RDNMADR_CODE
# ...

# %% [markdown]
# 위 데이터로는 각기 다른 도로명 코드를 얻기는 힘들 것 같다. 따라서 배달상점 도로명주소, 배달목적지 도로명주소가 '\N'으로 표기된 데이터는 본 분석에서 제외하도록 하였다.

# %%
# 전처리를 완료한 최종 구로구 데이터
final = guro[(guro['DLVR_STORE_RDNMADR_CODE'] != '\\N') & (guro['DLVR_DSTN_RDNMADR_CODE'] != '\\N')].reset_index(drop = True)
final
# Out:
#              SN  PROCESS_DT DLVR_REQUST_ENTRPS_ID  DLVR_REQUST_STTUS_VALUE  \
# 0       3486946  2019-12-01               C000049                        1
# 1       3486960  2019-12-01               C000049                        1
# 2       3486964  2019-12-01               C000049                        1
# 3       3486978  2019-12-01               C000049                        1
# 4       3486982  2019-12-01               C000049                        1
# ...         ...         ...                   ...                      ...
# 291495  7750299  2020-03-31               C000049                        1
# 291496  7750383  2020-03-31               C000210                        1
# 291497  7750456  2020-03-31               C000049                        1
# 291498  7750472  2020-03-31               C000049                        1
# 291499  7750480  2020-03-31               C000049                        1
#
#        DLVR_RCEPT_ENTRPS_ID DLVR_STORE_ID DLVR_STORE_INDUTY_NM  \
# ...

# %%
# to_csv로 파일 저장
final.to_csv('구로구 전처리 데이터.csv', index= False)

# %% [markdown]
# ### 주요 변경점
# - 배달이 취소된 데이터는 제외하였음. (DLVR_REQUST_STTUS_VALUE'] == 1)
# - 배달 상품금액이 0인 데이터 또한 3만개 가량 되었다. 상식적으로 배달 상품금액이 0인 것은 말이 안 된다. 기프티콘이나 쿠폰을 통해 구매한 것으로 보인다. 다만 차후 분석에서 배달금액을 통한 분석을 진행하기 때문에 제외하였다.
# - E+*로 표기된 도로명 주소를 정수로 변환하였음. 예로 1.15304E+11 -> 115304000000로 변환. 하지만 115304000000라는 도로명 번호를 가진 주소를 찾을 수 없었다.
# - 배달 상점 도로명코드, 배달 목적지 도로명코드가 '\N'로 저장된 데이터가 많았다. 다른 데이터와의 연관을 통해 유추하려 했지만 불가능해보였으므로 제외하였음.
