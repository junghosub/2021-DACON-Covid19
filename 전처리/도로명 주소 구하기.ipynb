# %%
import pandas as pd

# %%
guro = pd.read_excel('data/도로명정보조회(구로구).xls', header= 1)
guro.head()
# Out:
#    시군구    도로명번호       도로명                    로마자표기  읍면동일련번호    시도명 시군구명  \
# 0  구로구  1000115  수원문산고속도로  Suwon Munsan Expressway        0  서울특별시  구로구
# 1  구로구  2000003     남부순환로          Nambusunhwan-ro        0  서울특별시  구로구
# 2  구로구  2000003     남부순환로          Nambusunhwan-ro        1  서울특별시  구로구
# 3  구로구  2000003     남부순환로          Nambusunhwan-ro        2  서울특별시  구로구
# 4  구로구  2000003     남부순환로          Nambusunhwan-ro        3  서울특별시  구로구
#
#    읍면동구분  읍면동코드  읍면동명  시군구 코드
# 0      2    NaN   NaN   11530
# 1      2    NaN   NaN   11530
# 2      1  102.0   구로동   11530
# 3      1  103.0  가리봉동   11530
# 4      1  107.0   개봉동   11530

# %%
guemchoen = pd.read_excel('data/도로명정보조회(금천구).xls', header = 1)
guemchoen.head()
# Out:
#    시군구    도로명번호      도로명                로마자표기  읍면동일련번호    시도명 시군구명  읍면동구분  \
# 0  금천구  1000007  서해안고속도로  Seohaean Expressway        0  서울특별시  금천구      2
# 1  금천구  2000003    남부순환로      Nambusunhwan-ro        0  서울특별시  금천구      2
# 2  금천구  2000003    남부순환로      Nambusunhwan-ro        1  서울특별시  금천구      1
# 3  금천구  2000003    남부순환로      Nambusunhwan-ro        2  서울특별시  금천구      1
# 4  금천구  2005010     시흥대로        Siheung-daero        0  서울특별시  금천구      2
#
#    읍면동코드 읍면동명  시군구 코드
# 0    NaN  NaN   11545
# 1    NaN  NaN   11545
# 2  101.0  가산동   11545
# 3  102.0  독산동   11545
# 4    NaN  NaN   11545

# %%
yeondeung = pd.read_excel('data/도로명정보조회(영등포구).xls', header = 1)
yeondeung.head()
# Out:
#     시군구    도로명번호   도로명         로마자표기  읍면동일련번호    시도명  시군구명  읍면동구분  읍면동코드  \
# 0  영등포구  2005008  국회대로  Gukhoe-daero        0  서울특별시  영등포구      2    NaN
# 1  영등포구  2005008  국회대로  Gukhoe-daero        1  서울특별시  영등포구      1  108.0
# 2  영등포구  2005008  국회대로  Gukhoe-daero        2  서울특별시  영등포구      1  109.0
# 3  영등포구  2005008  국회대로  Gukhoe-daero        3  서울특별시  영등포구      1  110.0
# 4  영등포구  2005008  국회대로  Gukhoe-daero        4  서울특별시  영등포구      1  113.0
#
#      읍면동명  시군구 코드
# 0     NaN   11560
# 1  영등포동7가   11560
# 2  영등포동8가   11560
# 3    여의도동   11560
# 4   당산동3가   11560

# %%
gwangmyeong = pd.read_excel('data/도로명정보조회(광명시).xls', header= 1)
gwangmyeong.head()
# Out:
#    시군구    도로명번호       도로명                    로마자표기  읍면동일련번호  시도명 시군구명  읍면동구분  \
# 0  광명시  1000036  제2경인고속도로   Je2gyeongin Expressway        0  경기도  광명시      2
# 1  광명시  1000115  수원문산고속도로  Suwon Munsan Expressway        0  경기도  광명시      2
# 2  광명시  2000003     남부순환로          Nambusunhwan-ro        0  경기도  광명시      2
# 3  광명시  2000003     남부순환로          Nambusunhwan-ro        1  경기도  광명시      1
# 4  광명시  3000010      안양천로           Anyangcheon-ro        0  경기도  광명시      2
#
#    읍면동코드 읍면동명  시군구 코드
# 0    NaN  NaN   41210
# 1    NaN  NaN   41210
# 2    NaN  NaN   41210
# 3  102.0  철산동   41210
# 4    NaN  NaN   41210

# %%
yangcheon = pd.read_excel('data/도로명정보조회(양천구).xls', header = 1)
yangcheon.head()
# Out:
#    시군구    도로명번호       도로명                    로마자표기  읍면동일련번호    시도명 시군구명  \
# 0  양천구  1000028    경인고속도로      Gyeongin Expressway        0  서울특별시  양천구
# 1  양천구  1000115  수원문산고속도로  Suwon Munsan Expressway        0  서울특별시  양천구
# 2  양천구  2000003     남부순환로          Nambusunhwan-ro        0  서울특별시  양천구
# 3  양천구  2000003     남부순환로          Nambusunhwan-ro        1  서울특별시  양천구
# 4  양천구  2000003     남부순환로          Nambusunhwan-ro        2  서울특별시  양천구
#
#    읍면동구분  읍면동코드 읍면동명  시군구 코드
# 0      2    NaN  NaN   11470
# 1      2    NaN  NaN   11470
# 2      2    NaN  NaN   11470
# 3      1  101.0  신정동   11470
# 4      1  103.0  신월동   11470

# %%
gwanak = pd.read_excel('data/도로명정보조회(관악구).xls', header = 1)
gwanak.head()
# Out:
#    시군구    도로명번호    도로명            로마자표기  읍면동일련번호    시도명 시군구명  읍면동구분  읍면동코드  \
# 0  관악구  2000003  남부순환로  Nambusunhwan-ro        0  서울특별시  관악구      2    NaN
# 1  관악구  2000003  남부순환로  Nambusunhwan-ro        1  서울특별시  관악구      1  101.0
# 2  관악구  2000003  남부순환로  Nambusunhwan-ro        2  서울특별시  관악구      1  102.0
# 3  관악구  2000003  남부순환로  Nambusunhwan-ro        3  서울특별시  관악구      1  103.0
# 4  관악구  2000004   과천대로   Gwacheon-daero        0  서울특별시  관악구      2    NaN
#
#   읍면동명  시군구 코드
# 0  NaN   11620
# 1  봉천동   11620
# 2  신림동   11620
# 3  남현동   11620
# 4  NaN   11620

# %%
bucheon = pd.read_excel('data/도로명정보조회(부천시).xls', header = 1)
bucheon.head()
# Out:
#    시군구    도로명번호          도로명                           로마자표기  읍면동일련번호  시도명  \
# 0  부천시  1000028       경인고속도로             Gyeongin Expressway        0  경기도
# 1  부천시  1000115     수원문산고속도로         Suwon Munsan Expressway        0  경기도
# 2  부천시  1000140  수도권제1순환고속도로  Sudogwon Je1sunhwan Expressway        0  경기도
# 3  부천시  2000015         송내대로                   Songnae-daero        0  경기도
# 4  부천시  2000015         송내대로                   Songnae-daero        1  경기도
#
#   시군구명  읍면동구분  읍면동코드 읍면동명  시군구 코드
# 0  부천시      2    NaN  NaN   41190
# 1  부천시      2    NaN  NaN   41190
# 2  부천시      2    NaN  NaN   41190
# 3  부천시      2    NaN  NaN   41190
# 4  부천시      1  105.0  약대동   41190

# %%
dongjak = pd.read_excel('data/도로명정보조회(동작구).xls', header = 1)
dongjak.head()
# Out:
#    시군구    도로명번호    도로명            로마자표기  읍면동일련번호    시도명 시군구명  읍면동구분  읍면동코드  \
# 0  동작구  2000003  남부순환로  Nambusunhwan-ro        0  서울특별시  동작구      2    NaN
# 1  동작구  2000003  남부순환로  Nambusunhwan-ro        1  서울특별시  동작구      1  107.0
# 2  동작구  2005009   동작대로    Dongjak-daero        0  서울특별시  동작구      2    NaN
# 3  동작구  2005009   동작대로    Dongjak-daero        1  서울특별시  동작구      1  106.0
# 4  동작구  2005009   동작대로    Dongjak-daero        2  서울특별시  동작구      1  107.0
#
#   읍면동명  시군구 코드
# 0  NaN   11590
# 1  사당동   11590
# 2  NaN   11590
# 3  동작동   11590
# 4  사당동   11590

# %%
df = [guro, guemchoen, yeondeung, gwangmyeong, yangcheon, gwanak, bucheon, dongjak]

# %%
for row in df:
    row['시군구 코드'] = row['시군구 코드'].astype('string')
    row['도로명번호'] = row['도로명번호'].astype('string')
    row['도로명코드'] = row['시군구 코드'] + row['도로명번호']

# %%
list_of_df = [] 

for i in range(0, len(df)):
    df_temp = df[i]
    list_of_df.append(df_temp)
    
df_accum = pd.concat(list_of_df).reset_index(drop = True)

# %%
df_accum
# Out:
#        시군구    도로명번호        도로명                     로마자표기  읍면동일련번호    시도명 시군구명  \
# 0      구로구  1000115   수원문산고속도로   Suwon Munsan Expressway        0  서울특별시  구로구
# 1      구로구  2000003      남부순환로           Nambusunhwan-ro        0  서울특별시  구로구
# 2      구로구  2000003      남부순환로           Nambusunhwan-ro        1  서울특별시  구로구
# 3      구로구  2000003      남부순환로           Nambusunhwan-ro        2  서울특별시  구로구
# 4      구로구  2000003      남부순환로           Nambusunhwan-ro        3  서울특별시  구로구
# ...    ...      ...        ...                       ...      ...    ...  ...
# 11274  동작구  4860174  여의대방로20다길  Yeouidaebang-ro 20da-gil        1  서울특별시  동작구
# 11275  동작구  4860175  여의대방로20라길  Yeouidaebang-ro 20ra-gil        0  서울특별시  동작구
# 11276  동작구  4860175  여의대방로20라길  Yeouidaebang-ro 20ra-gil        1  서울특별시  동작구
# 11277  동작구  4860176  여의대방로20마길  Yeouidaebang-ro 20ma-gil        0  서울특별시  동작구
# 11278  동작구  4860176  여의대방로20마길  Yeouidaebang-ro 20ma-gil        1  서울특별시  동작구
#
# ...

# %%
df_accum['시군구'].value_counts()
# Out:
# 부천시     2957
# 영등포구    1776
# 관악구     1695
# 동작구     1411
# 구로구     1054
# 금천구      815
# 양천구      802
# 광명시      769
# Name: 시군구, dtype: int64

# %%
df_accum.to_csv('도로명정보조회.csv', index = False)

# %%
pd.read_csv('도로명정보조회.csv')
# Out:
#        시군구    도로명번호        도로명                     로마자표기  읍면동일련번호    시도명 시군구명  \
# 0      구로구  1000115   수원문산고속도로   Suwon Munsan Expressway        0  서울특별시  구로구
# 1      구로구  2000003      남부순환로           Nambusunhwan-ro        0  서울특별시  구로구
# 2      구로구  2000003      남부순환로           Nambusunhwan-ro        1  서울특별시  구로구
# 3      구로구  2000003      남부순환로           Nambusunhwan-ro        2  서울특별시  구로구
# 4      구로구  2000003      남부순환로           Nambusunhwan-ro        3  서울특별시  구로구
# ...    ...      ...        ...                       ...      ...    ...  ...
# 11274  동작구  4860174  여의대방로20다길  Yeouidaebang-ro 20da-gil        1  서울특별시  동작구
# 11275  동작구  4860175  여의대방로20라길  Yeouidaebang-ro 20ra-gil        0  서울특별시  동작구
# 11276  동작구  4860175  여의대방로20라길  Yeouidaebang-ro 20ra-gil        1  서울특별시  동작구
# 11277  동작구  4860176  여의대방로20마길  Yeouidaebang-ro 20ma-gil        0  서울특별시  동작구
# 11278  동작구  4860176  여의대방로20마길  Yeouidaebang-ro 20ma-gil        1  서울특별시  동작구
#
# ...
